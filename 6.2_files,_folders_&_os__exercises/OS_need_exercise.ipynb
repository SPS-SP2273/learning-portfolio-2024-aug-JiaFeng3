# %%
import os
import glob
import shutil

# %%
month_num = {
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}

# %%
os.chdir('C:\\Users\\tanji\\OneDrive\\Documents\\GitHub\\learning-portfolio-2024-aug-JiaFeng3\\6.2_files,_folders_&_os__exercises')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\tanji\\OneDrive\\Documents\\GitHub\\learning-portfolio-2024-aug-JiaFeng3\\6.2_files,_folders_&_os__exercises\\os-collaboration-exercise-data\\os-collaboration-exercise-data'

# %%
file = 'nov-08_singapore.txt'
for key in month_num:
    if key in file:
        x= file.replace(key,month_num[key]) .replace('_','-')
print(x)
# Out:
# 11-08-singapore.txt

# %%
def rename_my_file(old_file_name):
    for key in month_num:
        if key in old_file_name:
            y= old_file_name.replace(key,month_num[key]) .replace('_','-')
    return y

# %%
rename_my_file('jun-10_singapore.txt')
# Out:
# '06-10-singapore.txt'

# %%
Dates =['oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
 'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
 'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
 'jan-01_tokyo.txt']

# %%
date = []
for z in Dates:
    new_file=rename_my_file(z)
    date.append(new_file)
    print (f'{z} ----> {new_file}')
print(date)
# Out:
# oct-08_singapore.txt ----> 10-08-singapore.txt
# jul-10_cairo.txt ----> 07-10-cairo.txt
# may-15_dhaka.txt ----> 05-15-dhaka.txt
# may-13_cairo.txt ----> 05-13-cairo.txt
# oct-21_cairo.txt ----> 10-21-cairo.txt
# jan-10_singapore.txt ----> 01-10-singapore.txt
# jun-20_tokyo.txt ----> 06-20-tokyo.txt
# aug-06_jakarta.txt ----> 08-06-jakarta.txt
# dec-21_karachi.txt ----> 12-21-karachi.txt
# jan-01_tokyo.txt ----> 01-01-tokyo.txt
# ['10-08-singapore.txt', '07-10-cairo.txt', '05-15-dhaka.txt', '05-13-cairo.txt', '10-21-cairo.txt', '01-10-singapore.txt', '06-20-tokyo.txt', '08-06-jakarta.txt', '12-21-karachi.txt', '01-01-tokyo.txt']

# %%
text = glob.glob('os-collaboration-exercise-data/**/*.txt',recursive=True)

# %%
for t in text:
    Text = rename_my_file(t)
    os.rename(t,Text)

# %%
for t in text:
    Text = rename_my_file(t)
    print(Text)
# Out:
# os-collaboration-exercise-data\os-collaboration-exercise-data\04-01-melbourne.txt
# os-collaboration-exercise-data\os-collaboration-exercise-data\04-01-shanghai.txt
# os-collaboration-exercise-data\os-collaboration-exercise-data\04-01-singapore.txt
# os-collaboration-exercise-data\os-collaboration-exercise-data\04-02-cairo.txt
# os-collaboration-exercise-data\os-collaboration-exercise-data\04-02-jakarta.txt
# os-collaboration-exercise-data\os-collaboration-exercise-data\04-02-karachi.txt
# os-collaboration-exercise-data\os-collaboration-exercise-data\04-02-shanghai.txt
# os-collaboration-exercise-data\os-collaboration-exercise-data\04-03-manila.txt
# os-collaboration-exercise-data\os-collaboration-exercise-data\04-03-osaka.txt
# os-collaboration-exercise-data\os-collaboration-exercise-data\04-03-singapore.txt
# os-collaboration-exercise-data\os-collaboration-exercise-data\04-03-tokyo.txt
# os-collaboration-exercise-data\os-collaboration-exercise-data\04-04-manila.txt
# ...

# %%
cities = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']

# %%
os.mkdir('cities')

for city in cities:
    path = os.path.join('cities', city)
    print(f'Creating {path}')
    os.mkdir(path)
# Out:
# Creating cities\Cairo
# Creating cities\Dhaka
# Creating cities\Jakarta
# Creating cities\Karachi
# Creating cities\Manila
# Creating cities\Melbourne
# Creating cities\Osaka
# Creating cities\Shanghai
# Creating cities\Singapore
# Creating cities\Tokyo

# %%
os.chdir('os-collaboration-exercise-data')

# %%
print(os.getcwd())
# Out:
# C:\Users\tanji\OneDrive\Documents\GitHub\learning-portfolio-2024-aug-JiaFeng3\6.2_files,_folders_&_os__exercises\os-collaboration-exercise-data

# %%
A = glob.glob('os-collaboration-exercise-data/*******cairo.txt', recursive=True)

# %%
os.chdir('C:\\Users\\tanji\\OneDrive\\Documents\\GitHub\\learning-portfolio-2024-aug-JiaFeng3\\6.2_files,_folders_&_os__exercises')

# %%
shutil.copy(A, 'Cairo')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[126], line 1
# ----> 1 shutil.copy(A, 'Cairo')
#
# File ~\OneDrive\Documents\anaconda\Lib\shutil.py:435, in copy(src, dst, follow_symlinks)
#     433 if os.path.isdir(dst):
#     434     dst = os.path.join(dst, os.path.basename(src))
# --> 435 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     436 copymode(src, dst, follow_symlinks=follow_symlinks)
#     437 return dst
#
# File ~\OneDrive\Documents\anaconda\Lib\shutil.py:239, in copyfile(src, dst, follow_symlinks)
#     231 """Copy data from src to dst in the most efficient way possible.
#     232
#     233 If follow_symlinks is not set and src is a symbolic link, a new
#     234 symlink will be created instead of copying the file it points to.
#     235
#     236 """
#     237 sys.audit("shutil.copyfile", src, dst)
# --> 239 if _samefile(src, dst):
# ...
